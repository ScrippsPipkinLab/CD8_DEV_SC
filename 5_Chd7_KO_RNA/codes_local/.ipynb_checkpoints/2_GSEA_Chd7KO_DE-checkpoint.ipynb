# %%
##########----- Reused code -----##########
# Last update: Sept 13, 2020
# By: Huitian Diao
###########################################

library(stringr)

code_dir <- getwd()
tool_dir <- unlist(strsplit(code_dir,"/"))
tool_dir <- head(tool_dir, length(tool_dir)-2)
tool_dir <- paste(c(tool_dir, "tools"), collapse="/")
source(file.path(tool_dir, "function_GSEA.R"))
base_dir <- gsub("/codes_local", "", code_dir)
base_dir
# Out:
# [1] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA"

# %% [markdown]
# ## 1. GSEA analysis for each set of comparison

# %%
##########----- Parameters-----##########
genome <- "mm"
#########################################
sum.dir <- '/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/2_DE_GSEA'
dir.create(sum.dir, showWarnings = FALSE, recursive=TRUE)
setwd(sum.dir)

###----- Find all de files
de.out.dir <- '/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name'
de.files <- list.files(de.out.dir, pattern="*gn.csv", full.names=TRUE,recursive=TRUE)

use.cols <- c("gene_name", "log2FoldChange", "padj")

###----- Select gene signature
gs.dir <- file.path('/media/pipkin/ROCKET-PRO/T_cell_signature_Reference/X_GeneSignatures_mm')
gs.pattern <- paste("_", genome, "_sigs.csv", sep="")
gs.files <- list.files(gs.dir, pattern=gs.pattern, full.names=TRUE)
gs.files <- c(gs.files,'/media/pipkin/ROCKET-PRO/CD8_DEV_SC/9_Figures/2_IL2RAKO_Nascent/IL2_dependent_mm_sigs.csv',
              '/media/pipkin/ROCKET-PRO/CD8_DEV_SC/1_IL2RAKO/1_Scanpy/0-all_Scanpy_out/2_DE/D6-5_IL2_dependent_mm_sigs.csv')

# gs.files
gs.files <- c('/media/pipkin/ROCKET-PRO/T_cell_signature_Reference/X_GeneSignatures_mm/2020_mouse_CD8_mm_sigs.csv',
'/media/pipkin/ROCKET-PRO/T_cell_signature_Reference/X_GeneSignatures_mm/Exp391_CD8_mm_sigs.csv',
'/media/pipkin/ROCKET-PRO/CD8_DEV_SC/9_Figures/2_IL2RAKO_Nascent/IL2_dependent_mm_sigs.csv',
'/media/pipkin/ROCKET-PRO/CD8_DEV_SC/1_IL2RAKO/1_Scanpy/0-all_Scanpy_out/2_DE/D6-5_IL2_dependent_mm_sigs.csv')

gs.files
fc.cutoff <- 1
# Out:
# [1] "/media/pipkin/ROCKET-PRO/T_cell_signature_Reference/X_GeneSignatures_mm/2020_mouse_CD8_mm_sigs.csv"
# [2] "/media/pipkin/ROCKET-PRO/T_cell_signature_Reference/X_GeneSignatures_mm/Exp391_CD8_mm_sigs.csv"
# [3] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/9_Figures/2_IL2RAKO_Nascent/IL2_dependent_mm_sigs.csv"
# [4] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/1_IL2RAKO/1_Scanpy/0-all_Scanpy_out/2_DE/D6-5_IL2_dependent_mm_sigs.csv"

# %%
###----- Select comparisons
timepoints <- c("Naive","48h","EE","DP","MP","TE")
de.use.files <- c()

# Per timepoint KO vs WT
for (i in timepoints) {
    # i timepoint KO vs WT
    de.use.files <- c(de.use.files, file.path(de.out.dir,  paste("KO_", i, "-WT_", i, "-Salmon_gn.csv", sep="")))
}

# Act timepoint vs naive
act.timepoints <- c("48h","EE","DP","MP","TE")
for (i in act.timepoints){
    for (j in c("Naive")){
        if (i != j) {
            de.use.files <- c(de.use.files, file.path(de.out.dir,  paste("KO_", i, "-KO_", j, "-Salmon_gn.csv", sep="")))
            de.use.files <- c(de.use.files, file.path(de.out.dir,  paste("WT_", i, "-WT_", j, "-Salmon_gn.csv", sep="")))
        }
    }
}

# D8 one versus another
d8.timepoints <- c("EE","DP","MP","TE")
for (i_idx in c(1:4)){
    for (j_idx in c(1:4)){
        if (i_idx < j_idx) {
            i <- d8.timepoints[i_idx]
            j <- d8.timepoints[j_idx]
            de.use.files <- c(de.use.files, file.path(de.out.dir,  paste("KO_", i, "-KO_", j, "-Salmon_gn.csv", sep="")))
            de.use.files <- c(de.use.files, file.path(de.out.dir,  paste("WT_", i, "-WT_", j, "-Salmon_gn.csv", sep="")))
        }
    }
}

de.files.slt <- intersect(de.files, de.use.files)
print(length(de.files.slt))
de.files.slt
# Out:
# [1] 28
#  [1] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/KO_48h-KO_Naive-Salmon_gn.csv"
#  [2] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/KO_48h-WT_48h-Salmon_gn.csv"
#  [3] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/KO_DP-KO_MP-Salmon_gn.csv"
#  [4] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/KO_DP-KO_Naive-Salmon_gn.csv"
#  [5] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/KO_DP-KO_TE-Salmon_gn.csv"
#  [6] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/KO_DP-WT_DP-Salmon_gn.csv"
#  [7] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/KO_EE-KO_DP-Salmon_gn.csv"
#  [8] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/KO_EE-KO_MP-Salmon_gn.csv"
#  [9] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/KO_EE-KO_Naive-Salmon_gn.csv"
# [10] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/KO_EE-KO_TE-Salmon_gn.csv"
# [11] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/KO_EE-WT_EE-Salmon_gn.csv"
# [12] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/KO_MP-KO_Naive-Salmon_gn.csv"
# [13] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/KO_MP-KO_TE-Salmon_gn.csv"
# [14] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/KO_MP-WT_MP-Salmon_gn.csv"
# [15] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/KO_Naive-WT_Naive-Salmon_gn.csv"
# [16] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/KO_TE-KO_Naive-Salmon_gn.csv"
# [17] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/KO_TE-WT_TE-Salmon_gn.csv"
# [18] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/WT_48h-WT_Naive-Salmon_gn.csv"
# [19] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/WT_DP-WT_MP-Salmon_gn.csv"
# [20] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/WT_DP-WT_Naive-Salmon_gn.csv"
# [21] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/WT_DP-WT_TE-Salmon_gn.csv"
# [22] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/WT_EE-WT_DP-Salmon_gn.csv"
# [23] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/WT_EE-WT_MP-Salmon_gn.csv"
# [24] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/WT_EE-WT_Naive-Salmon_gn.csv"
# [25] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/WT_EE-WT_TE-Salmon_gn.csv"
# [26] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/WT_MP-WT_Naive-Salmon_gn.csv"
# [27] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/WT_MP-WT_TE-Salmon_gn.csv"
# [28] "/media/pipkin/ROCKET-PRO/CD8_DEV_SC/5_Chd7_KO_RNA/0_salmon_DE_out/2_DEseq/gene_name/WT_TE-WT_Naive-Salmon_gn.csv"

# %%
completed.df <- data.frame()
for (gs.file.i in c("file", gs.files)) {
    gs.file.base <- gsub(gs.pattern, "",basename(gs.file.i))
    completed.df[gs.file.base] <- character(0)
}
completed.name <- file.path(sum.dir, "completed.csv")

for (file.i in de.files.slt) {
    file.i.qc.row <- c(file.i)
    
    ###----- Create output names & output directory
    file.i.outpath <- gsub(de.out.dir, "", file.i)
    file.i.outpath <- gsub(".csv", "", file.i.outpath)
    file.i.outpath <- gsub("^/", "",file.i.outpath)

    file.i.simp.name <- tail(unlist(strsplit( file.i.outpath, "/")), 1)
    file.i.simp.name <- gsub("_differential", "", file.i.simp.name)
    file.i.simp.vec <- unlist(strsplit(file.i.simp.name, "_vs_"))

    # Create output directory
    file.i.dir <- file.path(sum.dir, paste(file.i.outpath, "_sep", sep=""))
    dir.create(file.i.dir, recursive=TRUE, showWarnings=FALSE)
    
    for (gs.file.i in gs.files) {
        gs.file.base <- gsub(gs.pattern, "",basename(gs.file.i))
        file.i.gs.dir <- file.path(file.i.dir, gs.file.base)
        dir.create(file.i.gs.dir, recursive=TRUE, showWarnings=FALSE)
        setwd(file.i.gs.dir)
        
        # Run GSEA analysis
        useGroup <- "log2FoldChange"
        outName <- file.i.simp.name
        
        success <- "yes"
        gsea <- tryCatch({
            GSEA_analysis(file.i, useGroup, outName, gs.file.i, fc.cutoff)
        }, error=function(cond) {
            message(paste(file.i, gs.file.i,sep='; '))
            return("no")
        })
        
        if (!is.null(gsea)){
            success <- ""
        }
        
        file.i.qc.row <- c(file.i.qc.row, success)
    }
    
    completed.df[nrow(completed.df) +1, ] <- file.i.qc.row
    write.csv(completed.df, completed.name, row.names=TRUE)
}
# Out:
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14543
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14543
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14543
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14543
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 7766
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 7766
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 7766
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 7766
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 7362
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 7362
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 7362
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 7362
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14760
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14760
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14760
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14760
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 7027
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 7027
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 7027
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 7027
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 6976
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 6976
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 6976
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 6976
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 7340
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 7340
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 7340
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 7340
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 7659
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 7659
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 7659
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 7659
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14006
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14006
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14006
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14006
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 6329
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 6329
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 6329
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 6329
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 6735
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 6735
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 6735
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 6735
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14438
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14438
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14438
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14438
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 7611
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 7611
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 7611
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 7611
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 9891
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 9891
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 9891
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 9891
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 10331
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 10331
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 10331
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 10331
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14484
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14484
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14484
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14484
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 6780
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 6780
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 6780
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 6780
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 15021
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 15021
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 15021
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 15021
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 9555
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 9555
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 9555
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 9555
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14931
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14931
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# ...
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 6963
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 6963
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 9872
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 9872
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 9872
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 9872
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 15196
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 15196
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 15196
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 15196
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 6624
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 6624
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 6624
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 6624
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 15189
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 15189
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 15189
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 15189
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 10169
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 10169
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 10169
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 10169
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14687
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14687
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14687
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
#
# ── Column specification ───────────────────────────────────
# cols(
#   gene_name = col_character(),
#   baseMean = col_double(),
#   log2FoldChange = col_double(),
#   lfcSE = col_double(),
#   stat = col_double(),
#   pvalue = col_double(),
#   padj = col_double()
# )
#
#
# Warning message:
# “Unknown columns: `gene_names`”
# [1] 14687
# ── Column specification ───────────────────────────────────
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
