# %%
import pandas as pd
import numpy as np
import os
import sys
from pathlib import Path

# %%
###----- Get dir & load / reload packages
try:
    code_dir
except NameError:
    print("Start")
    code_dir = os.getcwd()
    base_dir = code_dir.replace("/plotting_codes","")
    tools_dir = base_dir + "/tools"

    sys.path.insert(1, tools_dir)
    import sc_addons
    import sc_pl_addons

# %%
## ----- Setup working dir
sp_name = "0_Acute-Chronic"
analysis_name = ["0", "resampled"] 

wk_dir = base_dir + "/9_Figures/%s/%s_%s"%(sp_name, analysis_name[0], analysis_name[1])
Path(wk_dir).mkdir(parents=True, exist_ok=True)
os.chdir(wk_dir)

print(sp_name)
# Out:
# 0_Acute-Chronic

# %%
sum_file = 'louvain_celltype_general_withNAV_sum_plot/louvain_celltype_general_withNAV_gsea_all.csv'
sum_df = pd.read_csv(sum_file)

nodes_remove = ['P8_A', 'P1_C', 'P9_C', 'P10_C']

sum_df = sum_df[[True if x not in nodes_remove else False for x in sum_df['comparison']]]

# %%
sum_min_df = sum_df.groupby('pathway').min()
sum_min_df.to_csv("louvain_celltype_general_withNAV_sum_plot/louvain_celltype_general_withNAV_gsea_all_min-smallClustersRemoved.csv")

# %%
sum_min_df[sum_min]
# Out:
#                                           comparison       NES      padj  \
# pathway
# 2013_IMMUNITY_Locci---GC-Tfh                    P0_A -2.581864  0.000674
# 2013_IMMUNITY_Locci---non-GC-Tfh                P0_A -1.981718  0.000674
# 2014_IMMUNITY_Gaiha---HIV-EC_vs_HIV-CP_dn       P0_A -1.408548  0.111955
# 2014_IMMUNITY_Gaiha---HIV-EC_vs_HIV-CP_up       P0_A -2.155557  0.001833
# 2015_NAT_IMMUNOL_Choi---GC-Tfh                  P0_A -2.297401  0.000770
# ...                                              ...       ...       ...
# Exp391_CD8---d5_KLRG1hi_Runx3_repressed         P0_A -1.607774  0.000341
# Exp391_CD8---d5_KLRG1lo_Runx3_promoted          P0_A -2.546685  0.000348
# Exp391_CD8---d5_KLRG1lo_Runx3_repressed         P0_A -2.378785  0.000388
# Exp391_CD8---klf2_promoted                      P0_A -2.196577  0.000341
# Exp391_CD8---klf2_repressed                     P0_A -1.547510  0.001180
#
#                                                pval  leadingEdge_signal  \
# pathway
# 2013_IMMUNITY_Locci---GC-Tfh               0.000105                  19
# 2013_IMMUNITY_Locci---non-GC-Tfh           0.000117                  13
# 2014_IMMUNITY_Gaiha---HIV-EC_vs_HIV-CP_dn  0.025299                  13
# 2014_IMMUNITY_Gaiha---HIV-EC_vs_HIV-CP_up  0.000169                  10
# 2015_NAT_IMMUNOL_Choi---GC-Tfh             0.000110                  11
# ...                                             ...                 ...
# Exp391_CD8---d5_KLRG1hi_Runx3_repressed    0.000101                  22
# Exp391_CD8---d5_KLRG1lo_Runx3_promoted     0.000123                  21
# Exp391_CD8---d5_KLRG1lo_Runx3_repressed    0.000102                  19
# Exp391_CD8---klf2_promoted                 0.000101                  24
# Exp391_CD8---klf2_repressed                0.000663                   6
#
#                                            mlog10padj  mlog10pval old_names
# pathway
# 2013_IMMUNITY_Locci---GC-Tfh                 0.993160    1.221639       0_A
# 2013_IMMUNITY_Locci---non-GC-Tfh             0.004232    0.045616       0_A
# 2014_IMMUNITY_Gaiha---HIV-EC_vs_HIV-CP_dn    0.065608    0.125539       0_A
# 2014_IMMUNITY_Gaiha---HIV-EC_vs_HIV-CP_up    0.248499    0.286288       0_A
# 2015_NAT_IMMUNOL_Choi---GC-Tfh               0.007200    0.070869       0_A
# ...                                               ...         ...       ...
# Exp391_CD8---d5_KLRG1hi_Runx3_repressed      0.046136    0.053689       0_A
# Exp391_CD8---d5_KLRG1lo_Runx3_promoted       0.257691    0.287654       0_A
# Exp391_CD8---d5_KLRG1lo_Runx3_repressed      0.016018    0.023317       0_A
# Exp391_CD8---klf2_promoted                   0.893791    1.045652       0_A
# Exp391_CD8---klf2_repressed                  0.031990    0.031990       0_A
#
# [225 rows x 8 columns]
