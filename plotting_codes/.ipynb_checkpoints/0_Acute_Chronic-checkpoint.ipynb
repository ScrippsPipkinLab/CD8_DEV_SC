# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import copy
import sys
from importlib import reload
from pathlib import Path
import scanpy as sc
from pylab import rcParams
from matplotlib.patches import Patch

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

import scvelo as scv
scv.logging.print_version()


scv.settings.verbosity = 3  # show errors(0), warnings(1), info(2), hints(3)
scv.settings.set_figure_params('scvelo')  # for beautified visualization

# %matplotlib inline
# Out:
# <style>.container { width:90% !important; }</style>
# Running scvelo 0.2.2 (python 3.8.3) on 2020-09-18 14:23.

# %%
###----- Get dir & load / reload packages
try:
    code_dir
except NameError:
    print("Start")
    code_dir = os.getcwd()
    base_dir = code_dir.replace("/plotting_codes","")
    tools_dir = base_dir + "/tools"

    sys.path.insert(1, tools_dir)
    import sc_addons
    import sc_pl_addons
else:
    print("Reload")
    reload(sc_addons)
    reload(sc_pl_addons)
# Out:
# Reload

# %%
## ----- Setup working dir
sp_name = "0_Acute-Chronic"
analysis_name = ["0", "resampled"] 

wk_dir = base_dir + "/9_Figures/%s/%s_%s"%(sp_name, analysis_name[0], analysis_name[1])
Path(wk_dir).mkdir(parents=True, exist_ok=True)
os.chdir(wk_dir)

print(sp_name)
# Out:
# 0_Acute-Chronic

# %%
###----- old - new cluster names
order_file ='%s/%s/2_scVelo'%(base_dir, sp_name) + '/%s_scVelo_out_%s/pt_ordered_cluster_avg.csv'%(analysis_name[0], analysis_name[1])
order_df = pd.read_csv(order_file)
louvain_new_ordered = order_df['louvain_new_label'].tolist()
louvain_old_ordered = order_df['louvain'].tolist()

# %% [markdown]
# # 1. Scatterplots

# %%
adata_h5ad = '%s/%s/1_Scanpy'%(base_dir, sp_name) + '/%s_Scanpy_out_%s/%s_paga.h5ad'%(analysis_name[0], analysis_name[1], sp_name)
adata = sc.read_h5ad(adata_h5ad)


#--- Match old & new louvain levels
adata.obs['louvain_old'] = adata.obs['louvain']
adata.uns['louvain_old_colors'] = adata.uns['louvain_colors']
adata.obs['louvain'] = [ louvain_new_ordered[louvain_old_ordered.index(int(x))] for x in adata.obs['louvain'] ]
category_order = order_df.sort_values('louvain')['louvain_new_label'].tolist()
adata.obs['louvain'] = pd.Categorical(adata.obs['louvain'].tolist(), categories=category_order) # The key is to set categories according to original order...

# %%
### New louvain cluster numeric order plot
save_name = '_louvain_new_scatter.png'

### Plot
rcParams['figure.figsize'] = 4.5, 4.5

sc.pl.draw_graph(adata, color=['louvain'], legend_loc = "none", save = save_name )
# Out:
# WARNING: saving figure to file figures/draw_graph_fa_louvain_new_scatter.png

# %%
### New louvain cluster numeric order legend
save_name = '_louvain_new_scatter_leg.png'

### Plot
fig, ax=plt.subplots(figsize=(2,3))

phenotype_labels = ["" for x in louvain_new_ordered]

cpatch_elements = []
for i in range(0,len(louvain_new_ordered)):
    cpatch_elements.append(Patch(facecolor=adata.uns['louvain_colors'][louvain_old_ordered[i]], label="%s - %s" %(louvain_new_ordered[i], phenotype_labels[i])))

ax.add_artist(ax.legend(handles=cpatch_elements, loc=[0,0]))
ax.axis('off')
plt.show()
fig.savefig("figures/%s"%save_name)
plt.close()

# %%
### Original louvain cluster numeric order
save_name = '_louvain_old_scatter.png'

### Plot
rcParams['figure.figsize'] = 4.5, 4.5
sc.pl.draw_graph(adata, color=['louvain_old'], save=save_name)
# Out:
# WARNING: saving figure to file figures/draw_graph_fa_louvain_old_scatter.png

# %%
### New louvain cluster numeric order - Node plot
save_name = 'louvain_new_node.png'

### Plot
rcParams['figure.figsize'] = 5,5
sc.pl.paga(adata, color=['louvain'], save=save_name)
# Out:
# WARNING: saving figure to file figures/pagalouvain_new_node.png

# %%
### Hightlight by day
save_name = '_Arm_vs_Cl13---byDay.png'

### Plot
adata.obs['Armstrong'] = [x if "C" not in x else "" for x in adata.obs['cell_type']]
adata.obs['Armstrong'] = ["Naive" if x == 'NP14B' else "" if x == "" else "Day%s"%x[1] for x in adata.obs['Armstrong']]
adata.obs['Armstrong'] = pd.Categorical(adata.obs['Armstrong'].tolist(), categories=['', 'Naive','Day5', 'Day8']) 
adata.uns['Armstrong_colors'] = ['lightgrey', 'slategray', 'orange','maroon']

adata.obs['Clone13'] = [x if "A" not in x else "" for x in adata.obs['cell_type']]
adata.obs['Clone13'] = ["Naive" if x == 'NP14B' else "" if x == "" else "Day%s"%x[1] for x in adata.obs['Clone13']]
adata.obs['Clone13'] = pd.Categorical(adata.obs['Clone13'].tolist(), categories=['', 'Naive','Day5', 'Day8']) 
adata.uns['Clone13_colors'] = ['lightgrey', 'slategray', 'orange','maroon']

rcParams['figure.figsize'] = 5,5
sc.pl.draw_graph(adata, color=['Armstrong', 'Clone13'], save=save_name)
# Out:
# WARNING: saving figure to file figures/draw_graph_fa_Arm_vs_Cl13---byDay.png

# %% [markdown]
# ## 2. Distribution

# %%
adata.obs['cell_id'] = adata.obs.index.tolist()

# %%
adata.obs
# Out:
#                    cell_type  n_genes  percent_mito  n_counts y_pred  use  \
# AAACCCAAGAGGCGTT-1       C8P     2551      0.037982    8741.0   true  Yes
# AAACCCACAATGACCT-1       C5P     5384      0.040608   40854.0   true  Yes
# AAACCCACACGACAAG-1     NP14B     2428      0.046283    9377.0   true  Yes
# AAACCCACAGAGGTAC-1       A8T     1992      0.041353    5441.0   true  Yes
# AAACCCACAGCCGTTG-1       A8T     2281      0.051667    6329.0   true  Yes
# ...                      ...      ...           ...       ...    ...  ...
# TTTGGAGCAACTTGCA-1     NP14B     1527      0.055024    4707.0   true  Yes
# TTTGGTTAGGGTCAAC-1       C8P     2355      0.034483    7163.0   true  Yes
# TTTGGTTGTCACTTAG-1       A8P     1944      0.057811    5345.0   true  Yes
# TTTGGTTTCCGCGATG-1       A8P     1760      0.020218    4402.0   true  Yes
# TTTGTTGCACACGGTC-1       A8P     2324      0.019778    6219.0   true  Yes
#
#                    louvain day  dpt_pseudotime louvain_old Armstrong Clone13  \
# AAACCCAAGAGGCGTT-1      P8   8        0.935830           8              Day8
# AAACCCACAATGACCT-1      P2   5        0.878490           6              Day5
# AAACCCACACGACAAG-1      P0   0        0.000000           3     Naive   Naive
# AAACCCACAGAGGTAC-1     P10   8        0.950689           2      Day8
# AAACCCACAGCCGTTG-1      P7   8        0.893238           7      Day8
# ...                    ...  ..             ...         ...       ...     ...
# TTTGGAGCAACTTGCA-1      P0   0        0.027301           3     Naive   Naive
# TTTGGTTAGGGTCAAC-1      P8   8        0.942617           8              Day8
# TTTGGTTGTCACTTAG-1     P10   8        0.949120           2      Day8
# TTTGGTTTCCGCGATG-1     P10   8        0.947714           2      Day8
# TTTGTTGCACACGGTC-1      P9   8        0.934500           0      Day8
#
#                                cell_id cell_type_general
# AAACCCAAGAGGCGTT-1  AAACCCAAGAGGCGTT-1         Armstrong
# AAACCCACAATGACCT-1  AAACCCACAATGACCT-1         Armstrong
# AAACCCACACGACAAG-1  AAACCCACACGACAAG-1         Armstrong
# AAACCCACAGAGGTAC-1  AAACCCACAGAGGTAC-1         Armstrong
# AAACCCACAGCCGTTG-1  AAACCCACAGCCGTTG-1         Armstrong
# ...                                ...               ...
# TTTGGAGCAACTTGCA-1  TTTGGAGCAACTTGCA-1         Armstrong
# TTTGGTTAGGGTCAAC-1  TTTGGTTAGGGTCAAC-1         Armstrong
# TTTGGTTGTCACTTAG-1  TTTGGTTGTCACTTAG-1         Armstrong
# TTTGGTTTCCGCGATG-1  TTTGGTTTCCGCGATG-1         Armstrong
# TTTGTTGCACACGGTC-1  TTTGTTGCACACGGTC-1         Armstrong
#
# [7803 rows x 14 columns]

# %%
'A' in 'C8P'
# Out:
# False

# %%
adata.obs['cell_type_general'] = ["Armstrong" if "A" in x else "Clone13" if "C" in x else "Naive" for x in adata.obs['cell_type']]

# %%
fig, axes = plt.subplots(ncols=1, nrows=1, sharey=False, figsize=(5,3), constrained_layout = True, dpi=160)

col_list = ['grey', 'pink','crimson','chocolate','yellowgreen', 'dodgerblue','black']
sum_df = sc_pl_addons.count_pctg_stack_bars(adata,  'louvain', 'cell_type_general','cell_id', 
                                   None, None, axes, col_list,True)

# %%
sum_df.columns.tolist()
# Out:
# ['P9', 'P3', 'P10', 'P0', 'P5', 'P6', 'P2', 'P7', 'P8', 'P1', 'P4']

# %%
import re

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-6d1883448493> in <module>
# ----> 1 int(re.findall('\d+', "P1" ))
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'

# %%
filter(str.isdigit, "{1}")

# %%
# Out:
# 9

# %%
sum_df[new_colnames]
# Out:
#                           P0         P1         P2         P3         P4  \
# cell_type_general
# Armstrong           1.330377  99.401198  87.175043  51.770833  83.548387
# Clone13             0.110865   0.000000  10.225303  48.229167  16.451613
# Naive              98.558758   0.598802   2.599653   0.000000   0.000000
#
#                           P5         P6         P7         P8         P9  \
# cell_type_general
# Armstrong          65.116279  62.531017  20.990099   2.257336  98.407376
# Clone13            34.883721  37.468983  79.009901  97.742664   1.508801
# Naive               0.000000   0.000000   0.000000   0.000000   0.083822
#
#                          P10
# cell_type_general
# Armstrong          99.686192
# Clone13             0.209205
# Naive               0.104603
