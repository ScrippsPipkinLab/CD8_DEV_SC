# %%
code.dir <- getwd()

# %%
setwd(code.dir)
source("function_GSEA_nodeplot.R")
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.0     ✔ purrr   0.3.3
# ✔ tibble  3.0.0     ✔ dplyr   0.8.3
# ✔ tidyr   1.0.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
#
# Warning message:
# “package ‘tibble’ was built under R version 3.6.2”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter()  masks stats::filter()
# ✖ purrr::flatten() masks jsonlite::flatten()
# ✖ dplyr::lag()     masks stats::lag()
#
#
# Attaching package: ‘reshape2’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths

# %% [markdown]
# ## 1. Expr Differential GSEA node plots

# %%
wk.dir <- "/Users/yolandatiao/GSuiteScripps/Exp391_Acute-Chronic_SC/1_1_SCANPY_PAGA/all--numSlt-rmWTNAV/4_DE_GSEA/Cluster_vs_Cluster/node_plot_gsea"
setwd(wk.dir)

gs.file <- "/Users/yolandatiao/GSuiteScripps/Exp391_Acute-Chronic_SC/z_References/GSEA/Combined_GEO_GSEA_gs_order.csv"
paga.conn.file <- "/Users/yolandatiao/GSuiteScripps/Exp391_Acute-Chronic_SC/1_1_SCANPY_PAGA/all--numSlt-rmWTNAV/0_PAGA/all--numSlt-rmWTNAV_paga_connect_long_coor_newlabel.csv"
gsea.nes.file <-  "/Users/yolandatiao/GSuiteScripps/Exp391_Acute-Chronic_SC/1_1_SCANPY_PAGA/all--numSlt-rmWTNAV/4_DE_GSEA/Cluster_vs_Cluster/compiled_gsea_NES.csv"
gsea.pval.file <-  "/Users/yolandatiao/GSuiteScripps/Exp391_Acute-Chronic_SC/1_1_SCANPY_PAGA/all--numSlt-rmWTNAV/4_DE_GSEA/Cluster_vs_Cluster/compiled_gsea_pval.csv"

gsea_nodeplot(gs.file, paga.conn.file, gsea.nes.file, gsea.pval.file)

gsea_nodeplot(gs.file, paga.conn.file, gsea.nes.file, gsea.pval.file, "Tcf7_promoted")
# Out:
# Parsed with column specification:
# cols(
#   gs_name = col_character()
# )
#
# Parsed with column specification:
# cols(
#   Conn = col_double(),
#   node1 = col_character(),
#   node2 = col_character(),
#   x1 = col_double(),
#   y1 = col_double(),
#   x2 = col_double(),
#   y2 = col_double()
# )
#
# Warning message:
# “`as.tibble()` is deprecated as of tibble 2.0.0.
# Please use `as_tibble()` instead.
# The signature and semantics have changed, see `?as_tibble`.
# This warning is displayed once every 8 hours.
# Call `lifecycle::last_warnings()` to see where this warning was generated.”
# Parsed with column specification:
# cols(
#   gs_name = col_character()
# )
#
# Parsed with column specification:
# cols(
#   Conn = col_double(),
#   node1 = col_character(),
#   node2 = col_character(),
#   x1 = col_double(),
#   y1 = col_double(),
#   x2 = col_double(),
#   y2 = col_double()
# )
# plot without title

# %% [markdown]
# ## 2. Velocity Differential GSEA node plots

# %%
wk.dir <- "/Users/yolandatiao/GSuiteScripps/Exp391_Acute-Chronic_SC/1_2_scVelo/2_GSEA/Cluster_vs_Cluster/node_plot_gsea"

setwd(wk.dir)

gs.file <- "/Users/yolandatiao/GSuiteScripps/Exp391_Acute-Chronic_SC/z_References/GSEA/Combined_GEO_GSEA_gs_order.csv"
paga.conn.file <- "/Users/yolandatiao/GSuiteScripps/Exp391_Acute-Chronic_SC/1_1_SCANPY_PAGA/all--numSlt-rmWTNAV/0_PAGA/all--numSlt-rmWTNAV_paga_connect_long_coor_newlabel.csv"
gsea.nes.file <-  "/Users/yolandatiao/GSuiteScripps/Exp391_Acute-Chronic_SC/1_2_scVelo/2_GSEA/Cluster_vs_Cluster/compiled_gsea_NES.csv"
gsea.pval.file <-  "/Users/yolandatiao/GSuiteScripps/Exp391_Acute-Chronic_SC/1_2_scVelo/2_GSEA/Cluster_vs_Cluster/compiled_gsea_pval.csv"

gsea_nodeplot(gs.file, paga.conn.file, gsea.nes.file, gsea.pval.file)

gsea_nodeplot(gs.file, paga.conn.file, gsea.nes.file, gsea.pval.file, "Tcf7_promoted")
# Out:
# Parsed with column specification:
# cols(
#   gs_name = col_character()
# )
#
# Parsed with column specification:
# cols(
#   Conn = col_double(),
#   node1 = col_character(),
#   node2 = col_character(),
#   x1 = col_double(),
#   y1 = col_double(),
#   x2 = col_double(),
#   y2 = col_double()
# )
#
# Parsed with column specification:
# cols(
#   gs_name = col_character()
# )
#
# Parsed with column specification:
# cols(
#   Conn = col_double(),
#   node1 = col_character(),
#   node2 = col_character(),
#   x1 = col_double(),
#   y1 = col_double(),
#   x2 = col_double(),
#   y2 = col_double()
# )
# plot without title
