# %% [markdown]
# # SCANPY - PAGA - Differential analysis

# %%
#conda activate scRNA
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl
from matplotlib import rcParams
import scanpy as sc
import os
import csv
from astropy.io import ascii
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
from sklearn.cluster import DBSCAN
import warnings
from matplotlib_venn import venn3
from pathlib import Path
import sys
from itertools import combinations
from importlib import reload

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

warnings.filterwarnings('ignore')
code_dir = os.getcwd()
code_dir
sc.logging.print_versions()
# Out:
# <style>.container { width:90% !important; }</style>
# scanpy==1.5.1 anndata==0.7.3 umap==0.4.4 numpy==1.18.5 scipy==1.4.1 pandas==1.0.5 scikit-learn==0.23.1 statsmodels==0.11.1 python-igraph==0.8.2 louvain==0.6.1 leidenalg==0.8.1

# %%
code_dir = os.getcwd()
base_dir = code_dir.replace("/codes_local","")
parent_dir = "/".join(base_dir.split("/")[:-1])
tools_dir = parent_dir + "/tools"

sys.path.insert(1, tools_dir)
import sc_addons
reload(sc_addons)

sp_name = base_dir.split("/")[-1]
analysis_name = ["0", "resampled"]

wk_dir = base_dir + "/1_Scanpy/%s_Scanpy_out_%s"%(analysis_name[0],analysis_name[1])
Path(wk_dir).mkdir(parents=True, exist_ok=True)

print(sp_name, analysis_name)
# Out:
# 0_Acute-Chronic ['0', 'resampled']

# %% [markdown]
# -----

# %% [markdown]
# ### Info: Exp391 Expressional Level Differential Analysis
# 1. **Cluster v.s. Cluster** <br>
#     1.1 One v.s. all <br>
#     1.2 One v.s. one <br>
# <br>
# 2. **Armstrong v.s. Clone13** <br>
#     2.1 Armstrong v.s. Clone13 v.s. Naive in all cells <br>
#     2.2 Armstrong v.s. Clone13 in each cluster <br>
#     2.3 Armstrong v.s. Clone13 in each time point (day5, day8) <br>
#     2.4 Conditions v.s. Condition (Armstrong / Clone13 / Naive each time point one v.s. one)

# %% [markdown]
# -----

# %% [markdown]
# ## 0. Read object

# %%
#--- adata object
sp_h5ad = wk_dir + '/0_Scanpy_out/' + sp_name + '_paga.h5ad'
adata = sc.read_h5ad(sp_h5ad)

# Convert all cell type labels to general labels "A" "C" "N"
adata.obs['cell_type_general'] = [x[0] for x in adata.obs['cell_type']]
adata.obs['day'] = [x[1] for x in adata.obs['cell_type']]
adata.obs['day'] = [x.replace('P', '0') for x in adata.obs['day']]

# Number of genes in adata object
gene_n = len(adata.raw.var)
gene_n

# Get set of labels
louvain_newlabel_uniq = list(set(adata.obs['louvain_newlabel']))
louvain_newlabel_uniq.sort()
louvain_newlabel_uniq

#--- All genes from features.tsv
feature_file = base_dir + '/0_cellranger_outs_XL_folder/outs/filtered_feature_bc_matrix/features.tsv'
features_df = pd.read_csv(feature_file, header=None, sep='\t')
all_genes = list(features_df[1])

# %%
de_dir = wk_dir + '/2_DE'
Path(de_dir).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# -----

# %% [markdown]
# <h1><font size="8"><center> 2. Arm v.s. Cl13 </center></font></h1>

# %% [markdown]
# # 2.1 Differential Analysis for Arm v.s. Cl13 v.s. NAV All Cluster

# %%
# Working directory
cp_dir = de_dir + '/Arm_vs_Cl13'
Path(cp_dir).mkdir(parents=True, exist_ok=True)

# %%
### Config
obs_useCol = 'cell_type_general'
cps = ['wilcoxon', 't-test', 't-test_overestim_var']

label_useCol = 'cell_type_general'
labels_uniq = list(set(adata.obs[label_useCol]))
labels_uniq.sort()

### Compare
for i in labels_uniq:
    for j in labels_uniq:
        if i != j:
            adata_ij = adata.copy()
            adata_ij = adata_ij[[True if x in [i,j] else False for x in adata_ij.obs[label_useCol].values],:]
            sc_addons.multitest_venn(adata_ij, cps, obs_useCol, cp_dir)
# Out:
# ['A', 'C']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# A C wilcoxon
# A C t-test
# A C t-test_overestim_var
# C A wilcoxon
# C A t-test
# C A t-test_overestim_var
# ['A', 'N']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# A N wilcoxon
# A N t-test
# A N t-test_overestim_var
# N A wilcoxon
# N A t-test
# N A t-test_overestim_var
# ['A', 'C']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# A C wilcoxon
# A C t-test
# A C t-test_overestim_var
# C A wilcoxon
# C A t-test
# C A t-test_overestim_var
# ['C', 'N']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# C N wilcoxon
# C N t-test
# C N t-test_overestim_var
# N C wilcoxon
# N C t-test
# N C t-test_overestim_var
# ['A', 'N']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# A N wilcoxon
# A N t-test
# A N t-test_overestim_var
# N A wilcoxon
# N A t-test
# N A t-test_overestim_var
# ['C', 'N']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# C N wilcoxon
# C N t-test
# C N t-test_overestim_var
# N C wilcoxon
# N C t-test
# N C t-test_overestim_var

# %% [markdown]
# # 2.2 Differential Analysis for Arm v.s. Cl13 in each cluster

# %%
# Working directory
cp_dir = de_dir + '/perCluster_Arm_vs_Cl13'
Path(cp_dir).mkdir(parents=True, exist_ok=True)

# %%
### Config
obs_useCol = 'cell_type_general'
cps = ['wilcoxon', 't-test', 't-test_overestim_var']
obs_useTypes = ['A', 'C']

louvain_unique = [int(x) for x in list(set(adata.obs['louvain']))]
louvain_unique.sort()
louvain_unique = [str(x) for x in louvain_unique]

### Compare
for i in louvain_unique:
    cp_dir_i = cp_dir + '/' + i
    Path(cp_dir_i).mkdir(parents=True, exist_ok=True)
    
    adata_i = adata.copy()
    adata_i = adata_i[[True if x==i else False for x in adata_i.obs['louvain'].values], :]
    adata_i = adata_i[[True if x in obs_useTypes else False for x in adata_i.obs[obs_useCol].values], :]
    count_sum = adata_i.obs.reset_index()[['index',obs_useCol]].groupby(obs_useCol).count().T
    if (len(count_sum.columns) > 1) and (min(count_sum.iloc[0]) > 10):
        sc_addons.multitest_venn(adata_i, cps, obs_useCol, cp_dir_i)
# Out:
# ['A', 'C']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# A C wilcoxon
# A C t-test
# A C t-test_overestim_var
# C A wilcoxon
# C A t-test
# C A t-test_overestim_var
# ['A', 'C']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# A C wilcoxon
# A C t-test
# A C t-test_overestim_var
# C A wilcoxon
# C A t-test
# C A t-test_overestim_var
# ['A', 'C']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# A C wilcoxon
# A C t-test
# A C t-test_overestim_var
# C A wilcoxon
# C A t-test
# C A t-test_overestim_var
# ['A', 'C']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# A C wilcoxon
# A C t-test
# A C t-test_overestim_var
# C A wilcoxon
# C A t-test
# C A t-test_overestim_var
# ['A', 'C']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# A C wilcoxon
# A C t-test
# A C t-test_overestim_var
# C A wilcoxon
# C A t-test
# C A t-test_overestim_var
# ['A', 'C']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# A C wilcoxon
# A C t-test
# A C t-test_overestim_var
# C A wilcoxon
# C A t-test
# C A t-test_overestim_var
# ['A', 'C']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# A C wilcoxon
# A C t-test
# A C t-test_overestim_var
# C A wilcoxon
# C A t-test
# C A t-test_overestim_var

# %% [markdown]
# # 2.3 Differential Analysis for Arm v.s. Cl13 in each time point

# %%
# Working directory
cp_dir = de_dir + '/perTimepoint_Arm_vs_Cl13'
Path(cp_dir).mkdir(parents=True, exist_ok=True)

# %%
### Config
obs_useCol = 'cell_type_general'
cps = ['wilcoxon', 't-test', 't-test_overestim_var']
obs_useTypes = ['A', 'C']

day_use = ['5', '8']

### Compare
for i in day_use:
    cp_dir_i = cp_dir + '/' + "D" + i
    Path(cp_dir_i).mkdir(parents=True, exist_ok=True)
    
    adata_i = adata.copy()
    adata_i = adata_i[[True if x==i else False for x in adata_i.obs['day'].values], :]
    adata_i = adata_i[[True if x in obs_useTypes else False for x in adata_i.obs[obs_useCol].values], :]
    count_sum = adata_i.obs.reset_index()[['index',obs_useCol]].groupby(obs_useCol).count().T
    if (len(count_sum.columns) > 1) and (min(count_sum.iloc[0]) > 10):
        sc_addons.multitest_venn(adata_i, cps, obs_useCol, cp_dir_i)
# Out:
# ['A', 'C']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A C wilcoxon
# A C t-test
# A C t-test_overestim_var
# C A wilcoxon
# C A t-test
# C A t-test_overestim_var
# ['A', 'C']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A C wilcoxon
# A C t-test
# A C t-test_overestim_var
# C A wilcoxon
# C A t-test
# C A t-test_overestim_var

# %% [markdown]
# # 2.4 Cell type v.s. Cell type

# %%
# Working directory
cp_dir = de_dir + '/celltype_vs_celltype'
Path(cp_dir).mkdir(parents=True, exist_ok=True)

# %%
### Config
obs_useCol = 'cell_type'
cps = ['wilcoxon', 't-test', 't-test_overestim_var']

label_useCol = 'cell_type'
labels_uniq = list(set(adata.obs[label_useCol]))
labels_uniq.sort()

### Compare
for i in labels_uniq:
    for j in labels_uniq:
        if i != j:
            adata_ij = adata.copy()
            adata_ij = adata_ij[[True if x in [i,j] else False for x in adata_ij.obs[label_useCol].values],:]
            sc_addons.multitest_venn(adata_ij, cps, obs_useCol, cp_dir)
# Out:
# ['A5P', 'A5T']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A5P A5T wilcoxon
# A5P A5T t-test
# A5P A5T t-test_overestim_var
# A5T A5P wilcoxon
# A5T A5P t-test
# A5T A5P t-test_overestim_var
# ['A5P', 'A8P']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A5P A8P wilcoxon
# A5P A8P t-test
# A5P A8P t-test_overestim_var
# A8P A5P wilcoxon
# A8P A5P t-test
# A8P A5P t-test_overestim_var
# ['A5P', 'A8T']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A5P A8T wilcoxon
# A5P A8T t-test
# A5P A8T t-test_overestim_var
# A8T A5P wilcoxon
# A8T A5P t-test
# A8T A5P t-test_overestim_var
# ['A5P', 'C5P']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A5P C5P wilcoxon
# A5P C5P t-test
# A5P C5P t-test_overestim_var
# C5P A5P wilcoxon
# C5P A5P t-test
# C5P A5P t-test_overestim_var
# ['A5P', 'C8P']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A5P C8P wilcoxon
# A5P C8P t-test
# A5P C8P t-test_overestim_var
# C8P A5P wilcoxon
# C8P A5P t-test
# C8P A5P t-test_overestim_var
# ['A5P', 'NP14B']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A5P NP14B wilcoxon
# A5P NP14B t-test
# A5P NP14B t-test_overestim_var
# NP14B A5P wilcoxon
# NP14B A5P t-test
# NP14B A5P t-test_overestim_var
# ['A5P', 'A5T']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A5P A5T wilcoxon
# A5P A5T t-test
# A5P A5T t-test_overestim_var
# A5T A5P wilcoxon
# A5T A5P t-test
# A5T A5P t-test_overestim_var
# ['A5T', 'A8P']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A5T A8P wilcoxon
# A5T A8P t-test
# A5T A8P t-test_overestim_var
# A8P A5T wilcoxon
# A8P A5T t-test
# A8P A5T t-test_overestim_var
# ['A5T', 'A8T']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A5T A8T wilcoxon
# A5T A8T t-test
# A5T A8T t-test_overestim_var
# A8T A5T wilcoxon
# A8T A5T t-test
# A8T A5T t-test_overestim_var
# ['A5T', 'C5P']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A5T C5P wilcoxon
# A5T C5P t-test
# A5T C5P t-test_overestim_var
# C5P A5T wilcoxon
# C5P A5T t-test
# C5P A5T t-test_overestim_var
# ['A5T', 'C8P']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A5T C8P wilcoxon
# A5T C8P t-test
# A5T C8P t-test_overestim_var
# C8P A5T wilcoxon
# C8P A5T t-test
# C8P A5T t-test_overestim_var
# ['A5T', 'NP14B']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A5T NP14B wilcoxon
# A5T NP14B t-test
# A5T NP14B t-test_overestim_var
# NP14B A5T wilcoxon
# NP14B A5T t-test
# NP14B A5T t-test_overestim_var
# ['A5P', 'A8P']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A5P A8P wilcoxon
# A5P A8P t-test
# A5P A8P t-test_overestim_var
# A8P A5P wilcoxon
# A8P A5P t-test
# A8P A5P t-test_overestim_var
# ['A5T', 'A8P']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A5T A8P wilcoxon
# A5T A8P t-test
# A5T A8P t-test_overestim_var
# A8P A5T wilcoxon
# A8P A5T t-test
# A8P A5T t-test_overestim_var
# ['A8P', 'A8T']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A8P A8T wilcoxon
# A8P A8T t-test
# A8P A8T t-test_overestim_var
# A8T A8P wilcoxon
# A8T A8P t-test
# A8T A8P t-test_overestim_var
# ['A8P', 'C5P']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A8P C5P wilcoxon
# A8P C5P t-test
# A8P C5P t-test_overestim_var
# C5P A8P wilcoxon
# C5P A8P t-test
# C5P A8P t-test_overestim_var
# ['A8P', 'C8P']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A8P C8P wilcoxon
# A8P C8P t-test
# A8P C8P t-test_overestim_var
# C8P A8P wilcoxon
# C8P A8P t-test
# C8P A8P t-test_overestim_var
# ['A8P', 'NP14B']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A8P NP14B wilcoxon
# A8P NP14B t-test
# A8P NP14B t-test_overestim_var
# NP14B A8P wilcoxon
# NP14B A8P t-test
# NP14B A8P t-test_overestim_var
# ['A5P', 'A8T']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A5P A8T wilcoxon
# A5P A8T t-test
# A5P A8T t-test_overestim_var
# A8T A5P wilcoxon
# A8T A5P t-test
# A8T A5P t-test_overestim_var
# ['A5T', 'A8T']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A5T A8T wilcoxon
# A5T A8T t-test
# A5T A8T t-test_overestim_var
# A8T A5T wilcoxon
# A8T A5T t-test
# A8T A5T t-test_overestim_var
# ['A8P', 'A8T']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A8P A8T wilcoxon
# A8P A8T t-test
# A8P A8T t-test_overestim_var
# A8T A8P wilcoxon
# A8T A8P t-test
# A8T A8P t-test_overestim_var
# ['A8T', 'C5P']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A8T C5P wilcoxon
# A8T C5P t-test
# A8T C5P t-test_overestim_var
# C5P A8T wilcoxon
# C5P A8T t-test
# C5P A8T t-test_overestim_var
# ['A8T', 'C8P']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A8T C8P wilcoxon
# A8T C8P t-test
# A8T C8P t-test_overestim_var
# C8P A8T wilcoxon
# C8P A8T t-test
# C8P A8T t-test_overestim_var
# ['A8T', 'NP14B']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A8T NP14B wilcoxon
# A8T NP14B t-test
# A8T NP14B t-test_overestim_var
# NP14B A8T wilcoxon
# NP14B A8T t-test
# NP14B A8T t-test_overestim_var
# ['A5P', 'C5P']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A5P C5P wilcoxon
# A5P C5P t-test
# A5P C5P t-test_overestim_var
# C5P A5P wilcoxon
# C5P A5P t-test
# C5P A5P t-test_overestim_var
# ['A5T', 'C5P']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A5T C5P wilcoxon
# A5T C5P t-test
# A5T C5P t-test_overestim_var
# C5P A5T wilcoxon
# C5P A5T t-test
# C5P A5T t-test_overestim_var
# ['A8P', 'C5P']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A8P C5P wilcoxon
# A8P C5P t-test
# A8P C5P t-test_overestim_var
# C5P A8P wilcoxon
# C5P A8P t-test
# C5P A8P t-test_overestim_var
# ['A8T', 'C5P']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A8T C5P wilcoxon
# A8T C5P t-test
# A8T C5P t-test_overestim_var
# C5P A8T wilcoxon
# C5P A8T t-test
# C5P A8T t-test_overestim_var
# ['C5P', 'C8P']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# C5P C8P wilcoxon
# C5P C8P t-test
# C5P C8P t-test_overestim_var
# C8P C5P wilcoxon
# C8P C5P t-test
# C8P C5P t-test_overestim_var
# ['C5P', 'NP14B']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# C5P NP14B wilcoxon
# C5P NP14B t-test
# C5P NP14B t-test_overestim_var
# NP14B C5P wilcoxon
# NP14B C5P t-test
# NP14B C5P t-test_overestim_var
# ['A5P', 'C8P']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A5P C8P wilcoxon
# A5P C8P t-test
# A5P C8P t-test_overestim_var
# C8P A5P wilcoxon
# C8P A5P t-test
# C8P A5P t-test_overestim_var
# ['A5T', 'C8P']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A5T C8P wilcoxon
# A5T C8P t-test
# A5T C8P t-test_overestim_var
# C8P A5T wilcoxon
# C8P A5T t-test
# C8P A5T t-test_overestim_var
# ['A8P', 'C8P']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A8P C8P wilcoxon
# A8P C8P t-test
# A8P C8P t-test_overestim_var
# C8P A8P wilcoxon
# C8P A8P t-test
# C8P A8P t-test_overestim_var
# ['A8T', 'C8P']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A8T C8P wilcoxon
# A8T C8P t-test
# A8T C8P t-test_overestim_var
# C8P A8T wilcoxon
# C8P A8T t-test
# C8P A8T t-test_overestim_var
# ['C5P', 'C8P']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# C5P C8P wilcoxon
# C5P C8P t-test
# C5P C8P t-test_overestim_var
# C8P C5P wilcoxon
# C8P C5P t-test
# C8P C5P t-test_overestim_var
# ['C8P', 'NP14B']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# C8P NP14B wilcoxon
# C8P NP14B t-test
# C8P NP14B t-test_overestim_var
# NP14B C8P wilcoxon
# NP14B C8P t-test
# NP14B C8P t-test_overestim_var
# ['A5P', 'NP14B']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A5P NP14B wilcoxon
# A5P NP14B t-test
# A5P NP14B t-test_overestim_var
# NP14B A5P wilcoxon
# NP14B A5P t-test
# NP14B A5P t-test_overestim_var
# ['A5T', 'NP14B']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A5T NP14B wilcoxon
# A5T NP14B t-test
# A5T NP14B t-test_overestim_var
# NP14B A5T wilcoxon
# NP14B A5T t-test
# NP14B A5T t-test_overestim_var
# ['A8P', 'NP14B']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A8P NP14B wilcoxon
# A8P NP14B t-test
# A8P NP14B t-test_overestim_var
# NP14B A8P wilcoxon
# NP14B A8P t-test
# NP14B A8P t-test_overestim_var
# ['A8T', 'NP14B']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# A8T NP14B wilcoxon
# A8T NP14B t-test
# A8T NP14B t-test_overestim_var
# NP14B A8T wilcoxon
# NP14B A8T t-test
# NP14B A8T t-test_overestim_var
# ['C5P', 'NP14B']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# C5P NP14B wilcoxon
# C5P NP14B t-test
# C5P NP14B t-test_overestim_var
# NP14B C5P wilcoxon
# NP14B C5P t-test
# NP14B C5P t-test_overestim_var
# ['C8P', 'NP14B']
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell_type_general' as categorical
# Trying to set attribute `.obs` of view, copying.
# ... storing 'day' as categorical
# C8P NP14B wilcoxon
# C8P NP14B t-test
# C8P NP14B t-test_overestim_var
# NP14B C8P wilcoxon
# NP14B C8P t-test
# NP14B C8P t-test_overestim_var
