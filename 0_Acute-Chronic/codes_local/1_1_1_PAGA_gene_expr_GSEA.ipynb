# %%
code_dir <- getwd()

# %%
setwd(code_dir)
source("function_GSEA.R")

# %% [markdown]
# # 1. GSEA analysis per cluster

# %% [markdown]
# ### 1.1 Per cluster

# %%
wk.dir <- '/media/pipkin/Yolanda/Exp391_Acute-Chronic_SC/1_1_SCANPY_PAGA/all--numSlt-rmWTNAV/3_GSEA/sep'
setwd(wk.dir)

z.file <- '/media/pipkin/Yolanda/Exp391_Acute-Chronic_SC/1_1_SCANPY_PAGA/all--numSlt-rmWTNAV/1_norm_counts/all_norm_counts_named_c10_nbPctl_Z_naOmit--allNumSltrmWTNAV_z.csv'
z.tb <- read_csv(z.file)

gs.all.file <- '/media/pipkin/Yolanda/Exp391_Acute-Chronic_SC/z_References/GSEA/Combined_GEO_GSEA_signatures.csv'

for (i in tail(colnames(z.tb), -1)){
    useGroup <- i
    outName <- paste("allNumSltRmNAV_z", useGroup, sep="_")
    GSEA_analysis(z.file, useGroup, outName, gs.all.file, 1)
}
# Out:
# Parsed with column specification:
# cols(
#   gene_name = col_character(),
#   `0` = col_double(),
#   `1` = col_double(),
#   `2` = col_double(),
#   `3` = col_double(),
#   `4` = col_double(),
#   `5` = col_double(),
#   `6` = col_double(),
#   `7` = col_double(),
#   `8` = col_double()
# )
#
# Parsed with column specification:
# cols(
#   gene_name = col_character(),
#   `0` = col_double(),
#   `1` = col_double(),
#   `2` = col_double(),
#   `3` = col_double(),
#   `4` = col_double(),
#   `5` = col_double(),
#   `6` = col_double(),
#   `7` = col_double(),
#   `8` = col_double()
# )
#
# Parsed with column specification:
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
# Warning message:
# “Removed 1 rows containing missing values (geom_rect).”
# Warning message:
# ...

# %% [markdown]
# ### 1.2 Per cluster seperate cell type

# %%
wk.dir <- '/media/pipkin/Yolanda/Exp391_Acute-Chronic_SC/1_1_SCANPY_PAGA/all--numSlt-rmWTNAV/3_GSEA/sep_typeLouvain'
setwd(wk.dir)

z.file <- '/media/pipkin/Yolanda/Exp391_Acute-Chronic_SC/1_1_SCANPY_PAGA/all--numSlt-rmWTNAV/1_norm_counts/all_norm_counts_named_c10_nbPctl_Z_naOmit--allNumSltrmWTNAV_typeLouvain_z.csv'
z.tb <- read_csv(z.file)

gs.all.file <- '/media/pipkin/Yolanda/Exp391_Acute-Chronic_SC/z_References/GSEA/Combined_GEO_GSEA_signatures.csv'

for (i in tail(colnames(z.tb), -1)){
    useGroup <- i
    outName <- useGroup
    GSEA_analysis(z.file, useGroup, outName, gs.all.file, 1)
}
# Out:
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   gene_name = col_character()
# )
#
# See spec(...) for full column specifications.
#
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   gene_name = col_character()
# )
#
# See spec(...) for full column specifications.
#
# Parsed with column specification:
# cols(
#   gs_name = col_character(),
#   gene_symbol = col_character()
# )
#
# preparing geneSet collections...
#
# calculating observed enrichment scores...
#
# calculating permutation scores...
#
# calculating p values...
#
# leading edge analysis...
#
# done...
#
# Warning message:
# “Removed 2 rows containing missing values (geom_rect).”
# Warning message:
# “Removed 1 rows containing missing values (geom_rect).”
# Warning message:
# “Removed 2 rows containing missing values (geom_rect).”
# Warning message:
# “Removed 1 rows containing missing values (geom_rect).”
# Parsed with column specification:
# cols(
# ...

# %% [markdown]
# # 2. GSEA analysis summary

# %%
wk.dir <- '/media/pipkin/Yolanda/Exp391_Acute-Chronic_SC/1_1_SCANPY_PAGA/all--numSlt-rmWTNAV/3_GSEA'
setwd(wk.dir)

# %%
gsea.files.path <- '/media/pipkin/Yolanda/Exp391_Acute-Chronic_SC/1_1_SCANPY_PAGA/all--numSlt-rmWTNAV/3_GSEA/sep'
gsea.sum.name <- "Louvain_gsea"

obs.avg.file <-'/media/pipkin/Yolanda/Exp391_Acute-Chronic_SC/1_1_SCANPY_PAGA/all--numSlt-rmWTNAV/0_PAGA/all--numSlt-rmWTNAV_obs_louvainAvg.csv'
obs.avg.tb <- read_csv(obs.avg.file)
comp.order <- paste("allNumSltRmNAV_z_", obs.avg.tb$louvain, sep="")
#print(comp.order)

gsea.use.order <- '/media/pipkin/Yolanda/Exp391_Acute-Chronic_SC/z_References/GSEA/Combined_GEO_GSEA_gs_order.csv'
gsea.use.order.tb <- read_csv(gsea.use.order)
path.order <- gsea.use.order.tb$gs_name

gsea.files <- list.files(path = gsea.files.path, pattern = "*.csv", full.names = TRUE)

GSEA_sum(gsea.files, gsea.sum.name, 50, 16, TRUE, comp.order, TRUE, path.order)
# Out:
# Parsed with column specification:
# cols(
#   louvain = col_double(),
#   n_genes = col_double(),
#   percent_mito = col_double(),
#   n_counts = col_double(),
#   dpt_pseudotime = col_double(),
#   counts_per_gene = col_double()
# )
#
# Parsed with column specification:
# cols(
#   gs_name = col_character()
# )
#
# Parsed with column specification:
# cols(
#   ID = col_character(),
#   Description = col_character(),
#   setSize = col_double(),
#   enrichmentScore = col_double(),
#   NES = col_double(),
#   pvalue = col_double(),
#   p.adjust = col_double(),
#   qvalues = col_double(),
#   rank = col_double(),
#   leading_edge = col_character(),
#   core_enrichment = col_character()
# )
#
# Parsed with column specification:
# cols(
#   ID = col_character(),
#   Description = col_character(),
#   setSize = col_double(),
#   enrichmentScore = col_double(),
#   NES = col_double(),
#   pvalue = col_double(),
#   p.adjust = col_double(),
#   qvalues = col_double(),
# ...

# %%
gsea.files.path <- '/media/pipkin/Yolanda/Exp391_Acute-Chronic_SC/1_1_SCANPY_PAGA/all--numSlt-rmWTNAV/3_GSEA/sep_typeLouvain'
gsea.sum.name <- "typeLouvain_gsea"

obs.avg.file <-'/media/pipkin/Yolanda/Exp391_Acute-Chronic_SC/1_1_SCANPY_PAGA/all--numSlt-rmWTNAV/0_PAGA/all--numSlt-rmWTNAV_obs_louvainAvg.csv'
obs.avg.tb <- read_csv(obs.avg.file)
comp.order <- rep(obs.avg.tb$louvain, each=3)
comp.order <- paste( comp.order, c("A","C","N"), sep="_")
#print(comp.order)

gsea.files <- list.files(path = gsea.files.path, pattern = "*.csv", full.names = TRUE)
gsea.file.base <- gsub("---Combined_GEO_GSEA_signatures.csv", "", basename(gsea.files))
comp.order <- intersect(comp.order, gsea.file.base)

gsea.use.order <- '/media/pipkin/Yolanda/Exp391_Acute-Chronic_SC/z_References/GSEA/Combined_GEO_GSEA_gs_order.csv'
gsea.use.order.tb <- read_csv(gsea.use.order)
path.order <- gsea.use.order.tb$gs_name

GSEA_sum(gsea.files, gsea.sum.name, 50, 30, TRUE, comp.order, TRUE, path.order)
# Out:
# Parsed with column specification:
# cols(
#   louvain = col_double(),
#   n_genes = col_double(),
#   percent_mito = col_double(),
#   n_counts = col_double(),
#   dpt_pseudotime = col_double(),
#   counts_per_gene = col_double()
# )
#
# Parsed with column specification:
# cols(
#   gs_name = col_character()
# )
#
# Parsed with column specification:
# cols(
#   ID = col_character(),
#   Description = col_character(),
#   setSize = col_double(),
#   enrichmentScore = col_double(),
#   NES = col_double(),
#   pvalue = col_double(),
#   p.adjust = col_double(),
#   qvalues = col_double(),
#   rank = col_double(),
#   leading_edge = col_character(),
#   core_enrichment = col_character()
# )
#
# Parsed with column specification:
# cols(
#   ID = col_character(),
#   Description = col_character(),
#   setSize = col_double(),
#   enrichmentScore = col_double(),
#   NES = col_double(),
#   pvalue = col_double(),
#   p.adjust = col_double(),
#   qvalues = col_double(),
# ...
