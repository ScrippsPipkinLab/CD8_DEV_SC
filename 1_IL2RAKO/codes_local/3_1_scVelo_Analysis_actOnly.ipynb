# %% [markdown]
# <h1 align="center"><font size="8"> scVelo Analysis </font></h1>
#
# > Huitian (Yolanda) Diao, Sept. 14 2020 <br>
# > Source: [Velocyto notebook](https://github.com/velocyto-team/velocyto-notebooks.git)
#
#
# - vlm object:
#     - Gene IDs: vlm.ra['Gene']
#     - Cell IDs: vlm.ca['CellID']

# %%
import os
import pandas as pd
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from sklearn.neighbors import NearestNeighbors
import copy
import sys
from importlib import reload
from pathlib import Path

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

import scvelo as scv
scv.logging.print_version()


scv.settings.verbosity = 3  # show errors(0), warnings(1), info(2), hints(3)
scv.settings.set_figure_params('scvelo')  # for beautified visualization

# %matplotlib inline
# Out:
# <style>.container { width:90% !important; }</style>
# Running scvelo 0.2.2 (python 3.8.3) on 2020-11-08 20:28.

# %%
code_dir = os.getcwd()
base_dir = code_dir.replace("/codes_local","")
parent_dir = "/".join(base_dir.split("/")[:-1])
tools_dir = parent_dir + "/tools"

sys.path.insert(1, tools_dir)
import sc_addons
reload(sc_addons)

sp_name = base_dir.split("/")[-1]
analysis_name = ["1", "ACTonly_Dyn"]

wk_dir = base_dir + "/2_scVelo/%s-%s_scVelo_out"%(analysis_name[0],analysis_name[1])
Path(wk_dir).mkdir(parents=True, exist_ok=True)
os.chdir(wk_dir)

print(sp_name, analysis_name)
# Out:
# 1_IL2RAKO ['1', 'ACTonly_Dyn']

# %% [markdown]
# ## 0. Read input

# %%
adata = scv.read(base_dir + '/2_scVelo/0-all_scVelo_out/1_IL2RAKO_scVelo_preNN.h5ad')
adata = adata[adata.obs['cell_type'] != 'P14NAV']

# %%
scv.pp.moments(adata, n_pcs=20, n_neighbors=20)
scv.pp.neighbors(adata, n_pcs=20, n_neighbors=20)

scv.tl.velocity(adata)
scv.tl.velocity_graph(adata)
# Out:
# computing neighbors
#     finished (0:00:03) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing velocities
#     finished (0:00:00) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# computing velocity graph
#     finished (0:00:00) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)

# %%
#adata.uns['louvain_colors'] = ['#1f77b4', '#ff7f0e', '#279e68', '#d62728', '#aa40fc', '#8c564b',
#                               '#e377c2', '#b5bd61', '#17becf', '#aec7e8', '#ffbb78'] # P4, P5, P6, P7

# %%
scv.pl.velocity_embedding_stream(adata, basis='paga', color=['louvain'], dpi=100)
# Out:
# Renamed 'paga' to convention 'X_paga' (adata.obsm).
# computing velocity embedding
#     finished (0:00:00) --> added
#     'velocity_paga', embedded velocity vectors (adata.obsm)

# %%
scv.tl.recover_dynamics(adata)
scv.tl.velocity(adata, mode='dynamical')
scv.tl.velocity_graph(adata)
# Out:
# recovering dynamics
#     finished (0:01:32) --> added
#     'fit_pars', fitted parameters for splicing dynamics (adata.var)
# computing velocities
#     finished (0:00:00) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# computing velocity graph
#     finished (0:00:00) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)

# %%
adata.write('%s_scVelo.h5ad'%sp_name, compression='gzip')
adata.write_csvs("scVelo")
# Out:
# writing .csv files to scVelo

# %% [markdown]
# -----

# %% [markdown]
# ## Reload point

# %%
adata = scv.read('%s_scVelo.h5ad'%sp_name)

# %%
adata.uns['neighbors']['distances'] = adata.obsp['distances']
adata.uns['neighbors']['connectivities'] = adata.obsp['connectivities']

scv.tl.paga(adata, groups='louvain', minimum_spanning_tree=False, use_time_prior=False)
df = scv.get_df(adata, 'paga/transitions_confidence', precision=2).T
df.style.background_gradient(cmap='Blues').format('{:.2g}')
# Out:
# running PAGA
#     finished (0:00:00) --> added
#     'paga/connectivities', connectivities adjacency (adata.uns)
#     'paga/connectivities_tree', connectivities subtree (adata.uns)
#     'paga/transitions_confidence', velocity transitions (adata.uns)
# WARNING: 'paga' found multiple times in obsm, uns.
# <style  type="text/css" >
#     #T_30bda172_222b_11eb_bc98_484d7ee6617frow0_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow0_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow0_col3 {
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow0_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow0_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow0_col6 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow0_col7 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow0_col8 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow0_col9 {
#             background-color:  #b5d4e9;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow1_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow1_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow1_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow1_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow1_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow1_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow1_col7 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow1_col8 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow1_col9 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow2_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow2_col1 {
#             background-color:  #cbdef1;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow2_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow2_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow2_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow2_col5 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow2_col6 {
#             background-color:  #c7dbef;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow2_col7 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow2_col8 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow2_col9 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow3_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow3_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow3_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow3_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow3_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow3_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow3_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow3_col7 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow3_col8 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow3_col9 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow4_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow4_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow4_col2 {
#             background-color:  #5ba3d0;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow4_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow4_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow4_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow4_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow4_col7 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow4_col8 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow4_col9 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow5_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow5_col1 {
#             background-color:  #79b5d9;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow5_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow5_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow5_col4 {
#             background-color:  #d4e4f4;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow5_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow5_col6 {
#             background-color:  #61a7d2;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow5_col7 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow5_col8 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_30bda172_222b_11eb_bc98_484d7ee6617frow5_col9 {
#             background-color:  #f7fbff;
#             color:  #000000;

# %%
scv.pl.paga(adata, basis='paga', size=50, alpha=.1,
            min_edge_width=2, node_size_scale=1.5, dpi=150)
